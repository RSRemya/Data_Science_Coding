# %% [markdown]
# # Creating Datasets by Making Dictionaries

# %%
d1 = {'key1':[1,2,3,4,5,"x"],
      'key2' : [7,8,9,10,11,12],
      'key3':[13,14,15,16,17,18],
      'key4':[19,20,21,22,23,24]
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(d1 )

# %%
d2 = {'key1':[1,2,3,4,5,"x"],
      'key2' : [7,8,"y",10,11,12],
      'key3':[13,14,15,16,17,18],
      'key4':[19,20,21,"z","as",24]
}

# %%
df2 = pd.DataFrame(d2)

# %%
df1
# Out:
#   key1  key2  key3  key4
# 0    1     7    13    19
# 1    2     8    14    20
# 2    3     9    15    21
# 3    4    10    16    22
# 4    5    11    17    23
# 5    x    12    18    24

# %%
df2
# Out:
#   key1 key2  key3 key4
# 0    1    7    13   19
# 1    2    8    14   20
# 2    3    y    15   21
# 3    4   10    16    z
# 4    5   11    17   as
# 5    x   12    18   24

# %% [markdown]
# # Merging

# %%
# Inner merge - taking common rows out of two datasets - intersection
pd.merge(df1,df2)
# Out:
#   key1 key2  key3 key4
# 0    1    7    13   19
# 1    2    8    14   20
# 2    x   12    18   24

# %%
#key1 will be common and other columns will be identified as different ones
#whereever key is having common elements, those records will be taken
pd.merge(df1,df2,how= 'inner',on= 'key1')
# Out:
#   key1  key2_x  key3_x  key4_x key2_y  key3_y key4_y
# 0    1       7      13      19      7      13     19
# 1    2       8      14      20      8      14     20
# 2    3       9      15      21      y      15     21
# 3    4      10      16      22     10      16      z
# 4    5      11      17      23     11      17     as
# 5    x      12      18      24     12      18     24

# %%
#key1 & key4 will be common and other columns(having same key 1 and key 4) will be identified as different ones
pd.merge(df1,df2,how= 'inner',on= ['key4','key1'])
# Out:
#   key1  key2_x  key3_x key4 key2_y  key3_y
# 0    1       7      13   19      7      13
# 1    2       8      14   20      8      14
# 2    3       9      15   21      y      15
# 3    x      12      18   24     12      18

# %%
#key1 & key4 will be common and other columns will be identified as different ones
# Here all elements in key 1 and key 4 of both datasets are taken
pd.merge(df1,df2,how= 'outer',on= ['key4','key1'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)
#   key1  key2_x  key3_x  key4 key2_y  key3_y
# 0    1     7.0    13.0  19.0      7    13.0
# 1    2     8.0    14.0  20.0      8    14.0
# 2    3     9.0    15.0  21.0      y    15.0
# 3    4    10.0    16.0  22.0    NaN     NaN
# 4    5    11.0    17.0  23.0    NaN     NaN
# 5    x    12.0    18.0  24.0     12    18.0
# 6    4     NaN     NaN     z     10    16.0
# 7    5     NaN     NaN    as     11    17.0

# %%
# All rows of df1 are taken, but if its not matching with rows of df2, then inplace of those rows NaN is written
pd.merge(df1,df2,how= 'left',on= 'key4')#keeping key4 to be common in both
# Out:
#   key1_x  key2_x  key3_x key4 key1_y key2_y  key3_y
# 0      1       7      13   19      1      7    13.0
# 1      2       8      14   20      2      8    14.0
# 2      3       9      15   21      3      y    15.0
# 3      4      10      16   22    NaN    NaN     NaN
# 4      5      11      17   23    NaN    NaN     NaN
# 5      x      12      18   24      x     12    18.0

# %%
# All rows of df2 are taken, but if its not matching with df1, then inplace of those rows NaN is written
pd.merge(df1,df2,how= 'right',on= 'key4')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)
#   key1_x  key2_x  key3_x  key4 key1_y key2_y  key3_y
# 0      1     7.0    13.0  19.0      1      7      13
# 1      2     8.0    14.0  20.0      2      8      14
# 2      3     9.0    15.0  21.0      3      y      15
# 3    NaN     NaN     NaN     z      4     10      16
# 4    NaN     NaN     NaN    as      5     11      17
# 5      x    12.0    18.0  24.0      x     12      18

# %% [markdown]
# ## Merging  - When column headers are different

# %%
d11 = {'a':[1,2,3,4,5,"x"],
      'b' : [7,8,9,10,11,12],
      'c':[13,14,15,16,17,18],
      'd':[19,20,21,22,23,24]
}

# %%
d12 = {'key1':[1,2,3,4,5,"x"],
      'key2' : [7,8,"y",10,11,12],
      'key3':[13,14,15,16,17,18],
      'key4':[19,20,21,"z","a",24]
}

# %%
df11 = pd.DataFrame(d11)

# %%
df11
# Out:
#    a   b   c   d
# 0  1   7  13  19
# 1  2   8  14  20
# 2  3   9  15  21
# 3  4  10  16  22
# 4  5  11  17  23
# 5  x  12  18  24

# %%
df12 = pd.DataFrame(d12)

# %%
df12
# Out:
#   key1 key2  key3 key4
# 0    1    7    13   19
# 1    2    8    14   20
# 2    3    y    15   21
# 3    4   10    16    z
# 4    5   11    17    a
# 5    x   12    18   24

# %%
pd.merge(df11, df12 , how = 'left' , left_on = 'a' , right_on='key1')
# Out:
#    a   b   c   d key1 key2  key3 key4
# 0  1   7  13  19    1    7    13   19
# 1  2   8  14  20    2    8    14   20
# 2  3   9  15  21    3    y    15   21
# 3  4  10  16  22    4   10    16    z
# 4  5  11  17  23    5   11    17    a
# 5  x  12  18  24    x   12    18   24

# %%
df1
# Out:
#   key1  key2  key3  key4
# 0    1     7    13    19
# 1    2     8    14    20
# 2    3     9    15    21
# 3    4    10    16    22
# 4    5    11    17    23
# 5    x    12    18    24

# %%
df2
# Out:
#   key1 key2  key3 key4
# 0    1    7    13   19
# 1    2    8    14   20
# 2    3    y    15   21
# 3    4   10    16    z
# 4    5   11    17   as
# 5    x   12    18   24

# %% [markdown]
# # Joining

# %%
d10 = {'key11':[1,2,3,4,5,"x"],
      'key21' : [7,8,9,10,11,12],
      'key31':[13,14,15,16,17,18],
      'key41':[19,20,21,22,23,24]
}

# %%
d20 = {'key1':[1,2,3,4,5,"x"],
      'key2' : [7,8,"y",10,11,12],
      'key3':[13,14,15,16,17,18],
      'key4':[19,20,21,"z","a",24]
}

# %%
df10 = pd.DataFrame(d10 , index = [1,2,3,4,5,6])

# %%
df20 = pd.DataFrame(d20, index=[1,2,3,4,5,'x'])

# %%
df10
# Out:
#   key11  key21  key31  key41
# 1     1      7     13     19
# 2     2      8     14     20
# 3     3      9     15     21
# 4     4     10     16     22
# 5     5     11     17     23
# 6     x     12     18     24

# %%
df20
# Out:
#   key1 key2  key3 key4
# 1    1    7    13   19
# 2    2    8    14   20
# 3    3    y    15   21
# 4    4   10    16    z
# 5    5   11    17    a
# x    x   12    18   24

# %%
df10.join(df20)
# Out:
#   key11  key21  key31  key41 key1 key2  key3 key4
# 1     1      7     13     19    1    7  13.0   19
# 2     2      8     14     20    2    8  14.0   20
# 3     3      9     15     21    3    y  15.0   21
# 4     4     10     16     22    4   10  16.0    z
# 5     5     11     17     23    5   11  17.0    a
# 6     x     12     18     24  NaN  NaN   NaN  NaN

# %%
# To get all elements of table in left, and wherever similar rows are missing right... fill it with NaN
df10.join(df20,how = 'left')
# Since this code and above code are giving same result.... so by default how = left
# Out:
#   key11  key21  key31  key41 key1 key2  key3 key4
# 1     1      7     13     19    1    7  13.0   19
# 2     2      8     14     20    2    8  14.0   20
# 3     3      9     15     21    3    y  15.0   21
# 4     4     10     16     22    4   10  16.0    z
# 5     5     11     17     23    5   11  17.0    a
# 6     x     12     18     24  NaN  NaN   NaN  NaN

# %%
# To get all elements of table in right, and wherever similar rows are missing left... fill it with NaN
df10.join(df20,how = 'right')
# Out:
#   key11  key21  key31  key41 key1 key2  key3 key4
# 1     1    7.0   13.0   19.0    1    7    13   19
# 2     2    8.0   14.0   20.0    2    8    14   20
# 3     3    9.0   15.0   21.0    3    y    15   21
# 4     4   10.0   16.0   22.0    4   10    16    z
# 5     5   11.0   17.0   23.0    5   11    17    a
# x   NaN    NaN    NaN    NaN    x   12    18   24

# %%
# Taking all the combination possible, all indexes are taken
df10.join(df20 , how = 'outer')
# Out:
#   key11  key21  key31  key41 key1 key2  key3 key4
# 1     1    7.0   13.0   19.0    1    7  13.0   19
# 2     2    8.0   14.0   20.0    2    8  14.0   20
# 3     3    9.0   15.0   21.0    3    y  15.0   21
# 4     4   10.0   16.0   22.0    4   10  16.0    z
# 5     5   11.0   17.0   23.0    5   11  17.0    a
# 6     x   12.0   18.0   24.0  NaN  NaN   NaN  NaN
# x   NaN    NaN    NaN    NaN    x   12  18.0   24

# %%
# Taking only common rows having same indexes
df10.join(df20 , how = 'inner')
# Out:
#   key11  key21  key31  key41 key1 key2  key3 key4
# 1     1      7     13     19    1    7    13   19
# 2     2      8     14     20    2    8    14   20
# 3     3      9     15     21    3    y    15   21
# 4     4     10     16     22    4   10    16    z
# 5     5     11     17     23    5   11    17    a

# %%
# Difference between merge and join:
# Join - Matches the indexes
# Merge - Checks for column value

# %% [markdown]
# # Concatenating

# %%
df10
# Out:
#   key11  key21  key31  key41
# 1     1      7     13     19
# 2     2      8     14     20
# 3     3      9     15     21
# 4     4     10     16     22
# 5     5     11     17     23
# 6     x     12     18     24

# %%
df20
# Out:
#   key1 key2  key3 key4
# 1    1    7    13   19
# 2    2    8    14   20
# 3    3    y    15   21
# 4    4   10    16    z
# 5    5   11    17    a
# x    x   12    18   24

# %%
# Joining one below another
pd.concat([df1,df2] , axis=0)
# Out:
#   key1 key2  key3 key4
# 0    1    7    13   19
# 1    2    8    14   20
# 2    3    9    15   21
# 3    4   10    16   22
# 4    5   11    17   23
# 5    x   12    18   24
# 0    1    7    13   19
# 1    2    8    14   20
# 2    3    y    15   21
# 3    4   10    16    z
# 4    5   11    17   as
# 5    x   12    18   24

# %%
pd.concat([df1,df2] )
# Out:
#   key1 key2  key3 key4
# 0    1    7    13   19
# 1    2    8    14   20
# 2    3    9    15   21
# 3    4   10    16   22
# 4    5   11    17   23
# 5    x   12    18   24
# 0    1    7    13   19
# 1    2    8    14   20
# 2    3    y    15   21
# 3    4   10    16    z
# 4    5   11    17   as
# 5    x   12    18   24

# %%
# Combining side by side
pd.concat([df1,df2] , axis=1)
# Out:
#   key1 key2  key3 key4 key1 key2  key3 key4
# 0    1    7    13   19    1    7    13   19
# 1    2    8    14   20    2    8    14   20
# 2    3    9    15   21    3    y    15   21
# 3    4   10    16   22    4   10    16    z
# 4    5   11    17   23    5   11    17   as
# 5    x   12    18   24    x   12    18   24

# %%
# Tesing for other datasets 
pd.concat([df10,df20] )
# Out:
#   key11  key21  key31  key41 key1 key2  key3 key4
# 1     1    7.0   13.0   19.0  NaN  NaN   NaN  NaN
# 2     2    8.0   14.0   20.0  NaN  NaN   NaN  NaN
# 3     3    9.0   15.0   21.0  NaN  NaN   NaN  NaN
# 4     4   10.0   16.0   22.0  NaN  NaN   NaN  NaN
# 5     5   11.0   17.0   23.0  NaN  NaN   NaN  NaN
# 6     x   12.0   18.0   24.0  NaN  NaN   NaN  NaN
# 1   NaN    NaN    NaN    NaN    1    7  13.0   19
# 2   NaN    NaN    NaN    NaN    2    8  14.0   20
# 3   NaN    NaN    NaN    NaN    3    y  15.0   21
# 4   NaN    NaN    NaN    NaN    4   10  16.0    z
# 5   NaN    NaN    NaN    NaN    5   11  17.0    a
# x   NaN    NaN    NaN    NaN    x   12  18.0   24

# %%
# Tesing for other datasets 
pd.concat([df10,df20], axis=1 )
# Out:
#   key11  key21  key31  key41 key1 key2  key3 key4
# 1     1    7.0   13.0   19.0    1    7  13.0   19
# 2     2    8.0   14.0   20.0    2    8  14.0   20
# 3     3    9.0   15.0   21.0    3    y  15.0   21
# 4     4   10.0   16.0   22.0    4   10  16.0    z
# 5     5   11.0   17.0   23.0    5   11  17.0    a
# 6     x   12.0   18.0   24.0  NaN  NaN   NaN  NaN
# x   NaN    NaN    NaN    NaN    x   12  18.0   24
